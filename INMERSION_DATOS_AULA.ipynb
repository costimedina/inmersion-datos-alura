# %% [markdown]
# <a href="https://colab.research.google.com/github/costimedina/inmersion-datos-alura/blob/main/INMERSION_DATOS_AULA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **AULA 01:** Bienvenido a nuestro primer encuentro de inmersión de datos

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd 

inmuebles = pd.read_csv('/content/drive/MyDrive/Alura_Latam_Python/inmuebles_bogota.csv')
inmuebles.head()
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Baños  Área              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor
# 0    $ 360.000.000
# 1    $ 670.000.000
# 2  $ 1.120.000.000
# 3    $ 890.000.000
# 4    $ 970.000.000

# %%
inmuebles.shape
# Out:
# (9520, 8)

# %%
inmuebles.columns
# Out:
# Index(['Tipo', 'Descripcion', 'Habitaciones', 'Baños', 'Área', 'Barrio', 'UPZ',
#        'Valor'],
#       dtype='object')

# %%
columnas = {'Baños':'Banos','Área':'Area'}
inmuebles = inmuebles.rename(columns=columnas)
inmuebles.sample(10)
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 2498         Casa                   Casa en venta en Cedritos             4
# 7196  Apartamento             Apartamento en venta en Kennedy             2
# 4424         Casa                   Casa en venta en Engativa             4
# 7285  Apartamento             Apartamento en venta en Kennedy             3
# 7352  Apartamento       Apartamento en venta en La Candelaria             3
# 3822  Apartamento            Apartamento en venta en Engativa             2
# 3144  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 88    Apartamento         Apartamento en venta en El Contador             3
# 345   Apartamento          Apartamento en venta en La Calleja             3
# 6585         Casa         Casa en venta en Rafael Uribe Uribe             7
#
#       Banos  Area              Barrio                                    UPZ  \
# 2498      4   161            Cedritos                                Usaquén
# 7196      1    36             Kennedy                        Kennedy Central
# 4424      3   108            Engativa                               Engativá
# 7285      2    53             Kennedy                        Kennedy Central
# 7352      1    53       La Candelaria                          La Candelaria
# 3822      1    47            Engativa                               Engativá
# 3144      2    90  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 88        3   206         El Contador                             Los Cedros
# 345       4   174          La Calleja  USAQUÉN: Country Club + Santa Bárbara
# 6585      3   180  Rafael Uribe Uribe                          Los Alcázares
#
#                 Valor
# 2498    $ 620.000.000
# 7196    $ 109.000.000
# 4424    $ 260.000.000
# 7285    $ 187.000.000
# 7352    $ 180.000.000
# 3822    $ 165.000.000
# 3144    $ 339.000.000
# 88      $ 990.000.000
# 345   $ 1.380.000.000
# 6585    $ 360.000.000

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 595.1+ KB

# %%
inmuebles.iloc[300]
# Out:
# Tipo                                Apartamento
# Descripcion     Apartamento en venta en Kennedy
# Habitaciones                                  2
# Banos                                         1
# Area                                         42
# Barrio                                  Kennedy
# UPZ                             Kennedy Central
# Valor                             $ 116.100.000
# Name: 300, dtype: object

# %%
inmuebles.iloc[0]
# Out:
# Tipo                                           Apartamento
# Descripcion     Apartamento en venta en Zona Noroccidental
# Habitaciones                                             3
# Banos                                                    2
# Area                                                    70
# Barrio                                  Zona Noroccidental
# UPZ                     CHAPINERO: Pardo Rubio + Chapinero
# Valor                                        $ 360.000.000
# Name: 0, dtype: object

# %%
inmuebles.iloc[300:305]
# Out:
#             Tipo                          Descripcion  Habitaciones  Banos  \
# 300  Apartamento      Apartamento en venta en Kennedy             2      1
# 301  Apartamento  Apartamento en venta en Chico Norte             2      2
# 302  Apartamento      Apartamento en venta en Kennedy             3      2
# 303  Apartamento      Apartamento en venta en Kennedy             3      2
# 304  Apartamento     Apartamento en venta en Cedritos             4      4
#
#      Area       Barrio                                 UPZ          Valor
# 300    42      Kennedy                     Kennedy Central  $ 116.100.000
# 301    95  Chico Norte  CHAPINERO: Chicó Lago + El Refugio  $ 980.000.000
# 302    54      Kennedy                     Kennedy Central  $ 237.000.000
# 303    67      Kennedy                     Kennedy Central  $ 320.000.000
# 304   132     Cedritos                             Usaquén  $ 530.000.000

# %%
inmuebles['Valor'][300]
# Out:
# '$ 116.100.000'

# %%
type(inmuebles['Valor'][300:305])
# Out:
# pandas.core.series.Series

# %%
inmuebles.columns
# Out:
# Index(['Tipo', 'Descripcion', 'Habitaciones', 'Banos', 'Area', 'Barrio', 'UPZ',
#        'Valor'],
#       dtype='object')

# %%
inmuebles.Area.mean()
# Out:
# 146.66470588235293

# %%
inmuebles.sample(100)
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 8441  Apartamento         Apartamento en venta en Los Rosales             1
# 2980  Apartamento             Apartamento en venta en Kennedy             3
# 5734  Apartamento            Apartamento en venta en El Chicó             2
# 497   Apartamento     Apartamento en venta en Chico Reservado             2
# 7897  Apartamento       Apartamento en venta en Villa Alsacia             2
# ...           ...                                         ...           ...
# 870   Apartamento  Apartamento en venta en Zona Noroccidental             4
# 5786  Apartamento      Apartamento en venta en Ciudad Bolívar             2
# 1044  Apartamento             Apartamento en venta en Usaquén             3
# 7736  Apartamento            Apartamento en venta en Cedritos             2
# 465   Apartamento            Apartamento en venta en Fontibón             2
#
#       Banos  Area              Barrio  \
# 8441      2    61         Los Rosales
# 2980      5   310             Kennedy
# 5734      3   104            El Chicó
# 497       3   138     Chico Reservado
# 7897      1    42       Villa Alsacia
# ...     ...   ...                 ...
# 870       4   274  Zona Noroccidental
# 5786      1    40      Ciudad Bolívar
# 1044      2   110             Usaquén
# 7736      2    79            Cedritos
# 465       2    44            Fontibón
#
#                                                     UPZ            Valor
# 8441                 CHAPINERO: Chicó Lago + El Refugio    $ 596.614.000
# 2980                                    Kennedy Central  $ 2.900.000.000
# 5734                 CHAPINERO: Chicó Lago + El Refugio    $ 720.000.000
# 497                  CHAPINERO: Chicó Lago + El Refugio    $ 620.000.000
# 7897                        KENNEDY: Castilla + Bavaria    $ 170.000.000
# ...                                                 ...              ...
# 870                  CHAPINERO: Pardo Rubio + Chapinero  $ 1.399.000.000
# 5786  CIUDAD BOLÍVAR: Monteblanco + El Tesoro + El M...    $ 142.000.000
# 1044                                            Usaquén    $ 640.000.000
# 7736                                            Usaquén    $ 330.000.000
# 465                                            Fontibón    $ 111.000.000
#
# [100 rows x 8 columns]

# %%
(inmuebles.Barrio == 'Chico Reservado')
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 9515    False
# 9516    False
# 9517    False
# 9518    False
# 9519    False
# Name: Barrio, Length: 9520, dtype: bool

# %%
sum((inmuebles.Barrio == 'Chico Reservado'))
# Out:
# 225

# %%
inmuebles_chico = (inmuebles.Barrio == 'Chico Reservado')
type(inmuebles_chico)
# Out:
# pandas.core.series.Series

# %%
chico_reservado = inmuebles[inmuebles_chico]
chico_reservado
# Out:
#              Tipo                              Descripcion  Habitaciones  \
# 2     Apartamento  Apartamento en venta en Chico Reservado             3
# 39    Apartamento  Apartamento en venta en Chico Reservado             1
# 72    Apartamento  Apartamento en venta en Chico Reservado             1
# 126   Apartamento  Apartamento en venta en Chico Reservado             3
# 143   Apartamento  Apartamento en venta en Chico Reservado             2
# ...           ...                                      ...           ...
# 9299  Apartamento  Apartamento en venta en Chico Reservado             3
# 9335  Apartamento  Apartamento en venta en Chico Reservado             3
# 9341  Apartamento  Apartamento en venta en Chico Reservado             2
# 9472  Apartamento  Apartamento en venta en Chico Reservado             3
# 9506  Apartamento  Apartamento en venta en Chico Reservado             3
#
#       Banos  Area           Barrio                                 UPZ  \
# 2         3   144  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 39        1    64  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 72        1    64  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 126       4   150  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 143       4   104  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# ...     ...   ...              ...                                 ...
# 9299      3   148  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 9335      3   176  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 9341      3   118  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 9472      1    49  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 9506      4   390  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
#
#                 Valor
# 2     $ 1.120.000.000
# 39      $ 495.000.000
# 72      $ 495.000.000
# 126   $ 1.300.000.000
# 143   $ 1.100.000.000
# ...               ...
# 9299    $ 780.000.000
# 9335    $ 850.000.000
# 9341    $ 700.000.000
# 9472    $ 200.000.000
# 9506  $ 3.200.000.000
#
# [225 rows x 8 columns]

# %%
chico_reservado.Area.mean()
# Out:
# 142.78666666666666

# %%
inmuebles.Area.mean()
# Out:
# 146.66470588235293

# %%
len(inmuebles.Barrio.value_counts())
# Out:
# 149

# %%
inmuebles.Barrio.value_counts()
# Out:
# Usaquén               1105
# Zona Noroccidental     877
# Bosa                   589
# Kennedy                589
# Cedritos               554
#                       ...
# Colinas De Suba          1
# La Estanzuela            1
# Roma                     1
# Alameda                  1
# Prado Veraniego          1
# Name: Barrio, Length: 149, dtype: int64

# %%
len(inmuebles.UPZ.value_counts())
# Out:
# 63

# %%
inmuebles_barrio = inmuebles.Barrio.value_counts()
inmuebles_barrio.plot.bar()
# Out:
# <Axes: >

# %%
inmuebles_barrio.head(10).plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# **DESAFIO**
#
# 1. Cálculo promedio de área de todos los inmuebles en los barrios en el dataset. El top ten más un gráfico.
# 2. Investigar sobre otros datos estadísticos, conteo, mediana, valores mínimos y máximos.
# 3. https://www.aluracursos.com/inmersion-datos/clases/clase01-tu-primer-colab-con-python-y-pandas

# %% [markdown]
# 1. Visualizar la cantidad de Barrios del Dataset

# %%
len(inmuebles.Barrio.value_counts())
# Out:
# 149

# %%
inmuebles.Barrio.value_counts()
# Out:
# Usaquén               1105
# Zona Noroccidental     877
# Bosa                   589
# Kennedy                589
# Cedritos               554
#                       ...
# Colinas De Suba          1
# La Estanzuela            1
# Roma                     1
# Alameda                  1
# Prado Veraniego          1
# Name: Barrio, Length: 149, dtype: int64

# %% [markdown]
# 2. Promedio de área de los inmuebles de cada Barrio

# %%
inmuebles_barrio_area = inmuebles.groupby('Barrio')['Area'].mean()
inmuebles_barrio_area
# Out:
# Barrio
# Alameda                97.000000
# Alhambra              190.411765
# Andes Norte           124.857143
# Antonio Nariño        163.062500
# Barrancas              70.200000
#                          ...
# Villa Maria           207.153846
# Villas De Granada      86.590909
# Villemar               76.888889
# Zona Franca            54.000000
# Zona Noroccidental    135.785633
# Name: Area, Length: 149, dtype: float64

# %% [markdown]
# 3. Top 10 de los barrios con mayor área y graficar

# %%
inmuebles_promedio_ordenado = inmuebles_barrio_area.sort_values(ascending=False)
inmuebles_promedio_ordenado
# Out:
# Barrio
# Modelia            4316.750000
# Libertador          642.000000
# Bosa Piamonte       400.000000
# La Soledad          378.625000
# Restrepo            336.500000
#                       ...
# La Merced            41.000000
# El Tunal             41.000000
# San Diego            40.666667
# La Macarena          37.000000
# Prado Veraniego      25.000000
# Name: Area, Length: 149, dtype: float64

# %%
inmuebles_promedio_ordenado.head(10).plot.bar()
# Out:
# <Axes: xlabel='Barrio'>

# %%
inmuebles.groupby('Barrio')['Area'].agg(['count','min','max','median'])
# Out:
#                     count  min   max  median
# Barrio
# Alameda                 1   97    97    97.0
# Alhambra               17   50   360   164.0
# Andes Norte             7   42   180   108.0
# Antonio Nariño         48   32   554    72.0
# Barrancas              15   63    78    75.0
# ...                   ...  ...   ...     ...
# Villa Maria            13   51   222   222.0
# Villas De Granada      22   50   260    64.0
# Villemar               18   45   224    59.0
# Zona Franca             1   54    54    54.0
# Zona Noroccidental    877   16  5458    78.0
#
# [149 rows x 4 columns]

# %% [markdown]
# ### **AULA 02**

# %%
inmuebles.sample(5)
# Out:
#              Tipo                            Descripcion  Habitaciones  Banos  \
# 8468         Casa        Casa en venta en Barrios Unidos             3      1
# 9158  Apartamento    Apartamento en venta en El Progreso             4      2
# 2671  Apartamento        Apartamento en venta en Kennedy             4      3
# 6684  Apartamento       Apartamento en venta en Cedritos             3      2
# 6249  Apartamento  Apartamento en venta en Santa Barbara             2      3
#
#       Area          Barrio                                    UPZ  \
# 8468    73  Barrios Unidos                              Los Andes
# 9158   121     El Progreso                              El Rincón
# 2671   115         Kennedy                        Kennedy Central
# 6684    75        Cedritos                                Usaquén
# 6249    81   Santa Barbara  USAQUÉN: Country Club + Santa Bárbara
#
#               Valor Moneda     Precio  Precio_Millon  Valor_m2_Millones  \
# 8468  $ 109.385.000      $  109385000         109.39               1.50
# 9158  $ 280.000.000      $  280000000         280.00               2.31
# 2671  $ 540.000.000      $  540000000         540.00               4.70
# 6684  $ 285.000.000      $  285000000         285.00               3.80
# 6249  $ 535.000.000      $  535000000         535.00               6.60
#
#       Valor_m2_Barrio
# 8468             2.96
# 9158             3.03
# 2671             3.38
# 6684             5.03
# 6249             5.85

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Tipo               9520 non-null   object
#  1   Descripcion        9520 non-null   object
#  2   Habitaciones       9520 non-null   int64
#  3   Banos              9520 non-null   int64
#  4   Area               9520 non-null   int64
#  5   Barrio             9520 non-null   object
#  6   UPZ                9478 non-null   object
#  7   Valor              9520 non-null   object
#  8   Moneda             9520 non-null   object
#  9   Precio             9520 non-null   object
#  10  Precio_Millon      9520 non-null   float64
#  11  Valor_m2_Millones  9520 non-null   float64
#  12  Valor_m2_Barrio    9520 non-null   float64
# dtypes: float64(3), int64(3), object(7)
# memory usage: 967.0+ KB

# %%
inmuebles.Valor[0]
# Out:
# '$ 360.000.000'

# %%
type(inmuebles.Valor[0])
# Out:
# str

# %%
inmuebles.Valor[0]+inmuebles.Valor[1]+inmuebles.Valor[:5]
# Out:
# 0      $ 360.000.000$ 670.000.000$ 360.000.000
# 1      $ 360.000.000$ 670.000.000$ 670.000.000
# 2    $ 360.000.000$ 670.000.000$ 1.120.000.000
# 3      $ 360.000.000$ 670.000.000$ 890.000.000
# 4      $ 360.000.000$ 670.000.000$ 970.000.000
# Name: Valor, dtype: object

# %%
inmuebles.Valor[0].split()
# Out:
# ['$', '360.000.000']

# %%
inmuebles.Valor.str.split()
# Out:
# 0         [$, 360.000.000]
# 1         [$, 670.000.000]
# 2       [$, 1.120.000.000]
# 3         [$, 890.000.000]
# 4         [$, 970.000.000]
#                ...
# 9515      [$, 290.000.000]
# 9516      [$, 670.000.000]
# 9517      [$, 900.000.000]
# 9518      [$, 335.000.000]
# 9519      [$, 144.990.000]
# Name: Valor, Length: 9520, dtype: object

# %%
type(inmuebles.Valor.str.split())
# Out:
# pandas.core.series.Series

# %%
valor = inmuebles.Valor.str.split(expand=True)
inmuebles['Moneda'] = valor[0]
inmuebles['Precio'] = valor[1]
inmuebles.sample(3)
# Out:
#              Tipo                       Descripcion  Habitaciones  Banos  \
# 1445  Apartamento  Apartamento en venta en Cedritos             3      3
# 2377         Casa      Casa en venta en Santa Paula             4      3
# 7740  Apartamento  Apartamento en venta en Engativa             3      2
#
#       Area       Barrio                                    UPZ  \
# 1445   112     Cedritos                                Usaquén
# 2377   220  Santa Paula  USAQUÉN: Country Club + Santa Bárbara
# 7740    87     Engativa                               Engativá
#
#                 Valor Moneda         Precio  Precio_Millon  Valor_m2_Millones  \
# 1445    $ 530.000.000      $    530.000.000         530.00               4.73
# 2377  $ 1.300.000.000      $  1.300.000.000        1300.00               5.91
# 7740    $ 480.000.000      $    480.000.000         480.00               5.52
#
#       Valor_m2_Barrio
# 1445             5.03
# 2377             6.49
# 7740             2.89

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Tipo               9520 non-null   object
#  1   Descripcion        9520 non-null   object
#  2   Habitaciones       9520 non-null   int64
#  3   Banos              9520 non-null   int64
#  4   Area               9520 non-null   int64
#  5   Barrio             9520 non-null   object
#  6   UPZ                9478 non-null   object
#  7   Valor              9520 non-null   object
#  8   Moneda             9520 non-null   object
#  9   Precio             9520 non-null   object
#  10  Precio_Millon      9520 non-null   float64
#  11  Valor_m2_Millones  9520 non-null   float64
#  12  Valor_m2_Barrio    9520 non-null   float64
# dtypes: float64(3), int64(3), object(7)
# memory usage: 967.0+ KB

# %%
inmuebles['Precio'].sum()
# Out:
# '360.000.000670.000.0001.120.000.000890.000.000970.000.000510.000.000500.000.0002.350.000.000850.000.000642.000.000652.000.000168.000.000205.000.000300.000.000680.000.0002.519.000.000420.000.000620.000.000239.000.0001.600.000.000420.000.000625.000.0002.799.000.0001.450.000.0002.000.000.000670.000.0001.800.000.000469.000.000580.000.000445.000.000261.500.000278.000.000258.000.000520.000.000200.000.000129.000.000350.000.000290.500.000750.000.000495.000.000285.000.000900.000.0001.800.000.000990.000.000418.000.000349.000.000565.000.000370.000.000259.000.000310.000.000354.000.000372.000.000500.000.000420.000.0001.050.000.000185.000.000349.000.000515.000.000287.000.000265.000.000500.000.000261.500.000300.000.000278.000.000258.000.000520.000.000350.000.000290.500.000129.000.000200.000.000750.000.000418.000.000495.000.000349.000.000310.000.000565.000.000370.000.000259.000.000354.000.000285.000.000420.000.000372.000.000500.000.000185.000.0001.050.000.000349.000.0001.800.000.000900.000.000990.000.000225.000.000148.000.000331.500.000300.000.0001.030.000.000195.000.000200.000.000168.000.000323.000.000275.000.000510.000.000176.000.000680.000.000680.000.000217.000.0001.050.000.000375.000.000458.000.0002.000.000.000425.000.000318.000.000660.000.000730.000.000140.000.000343.000.000385.000.0001.300.000.0001.195.000.000519.000.000350.000.000202.000.000429.000.000640.000.000435.000.000610.000.000650.000.000421.000.0001.300.000.000155.000.000530.000.000330.000.000225.000.000143.000.000245.500.000433.000.000315.000.000450.000.000350.000.000205.000.0001.200.000.000169.000.000375.000.000460.000.000308.000.0001.100.000.000400.000.000860.000.0001.650.000.000565.000.000238.000.000503.000.000330.000.000400.000.0001.650.000.000580.000.000503.000.000635.000.000499.000.000371.000.000179.000.000348.200.000238.000.000173.000.000257.000.0001.100.000.000298.500.000680.000.000680.000.000217.000.0001.050.000.000375.000.000660.000.000318.000.000458.000.000425.000.0002.000.000.000343.000.000730.000.000140.000.0001.300.000.000385.000.000369.000.000366.000.000378.000.000355.000.000700.000.000990.000.000600.000.000516.000.000350.000.000475.000.000749.000.0001.195.000.000498.000.000269.000.000153.000.000335.000.000399.000.000373.000.000415.000.0001.550.000.000460.000.000225.000.000200.000.000234.000.000199.000.000450.000.0001.400.000.000202.000.000350.000.000519.000.000310.000.000355.000.000545.000.000720.000.000650.000.000343.000.000127.000.000370.000.000162.000.0001.560.000.000136.000.000265.000.000131.000.000416.000.000161.000.000900.000.000389.000.000190.000.000139.000.000319.000.000327.000.000474.500.000308.000.000720.000.000310.000.000177.500.0001.200.000.000380.000.000210.000.0001.290.000.000320.000.000445.000.000340.000.000510.000.000465.000.000220.000.000337.000.000260.000.000445.000.000290.000.000342.514.000625.000.000490.000.000350.000.000444.150.000360.000.000370.000.000150.000.000232.500.000271.000.000450.000.000163.500.000390.000.000300.000.000406.000.000465.000.000390.000.000175.000.000445.000.000422.000.000690.000.000445.000.000357.000.000465.000.000164.000.000300.000.000406.000.0001.700.000.000570.000.000460.000.000960.000.000510.000.000520.000.000142.000.000750.000.000160.000.000445.000.000570.000.000319.981.523510.000.000380.000.000134.000.000120.000.000460.000.000560.000.000351.000.0001.390.000.000422.000.000260.000.000980.000.000116.100.000980.000.000237.000.000320.000.000530.000.000503.000.000117.000.0001.300.000.000477.000.000450.000.000515.000.000730.000.000600.000.000480.000.000560.000.000308.000.000365.000.0001.200.000.000371.000.000850.000.000428.000.000421.000.000650.000.000295.000.000144.000.000280.000.000162.000.000620.000.0001.200.000.000360.000.000350.000.000650.000.000560.000.000295.000.000413.500.0001.200.000.000370.000.000600.000.000390.000.000447.500.000132.000.000180.000.000285.000.000620.000.000400.000.0001.380.000.000335.238.800820.000.000545.000.000217.000.000495.000.000330.000.000570.000.000280.000.0002.000.000.000390.000.000311 ...

# %%
inmuebles['Precio'] = inmuebles['Precio'].str.replace('.','',regex=True)

# %%
inmuebles[['Precio','Barrio']]
# Out:
#           Precio                  Barrio
# 0      360000000      Zona Noroccidental
# 1      670000000                Castilla
# 2     1120000000         Chico Reservado
# 3      890000000                 Usaquén
# 4      970000000             Bella Suiza
# ...          ...                     ...
# 9515   290000000                 Kennedy
# 9516   670000000  Parque Central Bavaria
# 9517   900000000                Restrepo
# 9518   335000000                Engativa
# 9519   144990000                 Tintala
#
# [9520 rows x 2 columns]

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Tipo               9520 non-null   object
#  1   Descripcion        9520 non-null   object
#  2   Habitaciones       9520 non-null   int64
#  3   Banos              9520 non-null   int64
#  4   Area               9520 non-null   int64
#  5   Barrio             9520 non-null   object
#  6   UPZ                9478 non-null   object
#  7   Valor              9520 non-null   object
#  8   Moneda             9520 non-null   object
#  9   Precio             9520 non-null   object
#  10  Precio_Millon      9520 non-null   float64
#  11  Valor_m2_Millones  9520 non-null   float64
#  12  Valor_m2_Barrio    9520 non-null   float64
# dtypes: float64(3), int64(3), object(7)
# memory usage: 967.0+ KB

# %%
inmuebles['Precio_Millon'] = inmuebles.Precio.astype('float')/1000000
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Tipo               9520 non-null   object
#  1   Descripcion        9520 non-null   object
#  2   Habitaciones       9520 non-null   int64
#  3   Banos              9520 non-null   int64
#  4   Area               9520 non-null   int64
#  5   Barrio             9520 non-null   object
#  6   UPZ                9478 non-null   object
#  7   Valor              9520 non-null   object
#  8   Moneda             9520 non-null   object
#  9   Precio             9520 non-null   object
#  10  Precio_Millon      9520 non-null   float64
#  11  Valor_m2_Millones  9520 non-null   float64
#  12  Valor_m2_Barrio    9520 non-null   float64
# dtypes: float64(3), int64(3), object(7)
# memory usage: 967.0+ KB

# %%
inmuebles.describe()
# Out:
#        Habitaciones   Banos      Area  Precio_Millon  Valor_m2_Millones  \
# count       9520.00 9520.00   9520.00        9520.00            9520.00
# mean           3.07    2.45    146.66         602.06               5.01
# std            2.05    1.26   1731.38         704.60               2.37
# min            1.00    0.00      2.00          60.00               0.01
# 25%            2.00    2.00     57.00         250.00               3.48
# 50%            3.00    2.00     80.00         409.18               4.67
# 75%            3.00    3.00    135.00         680.00               6.12
# max          110.00    9.00 166243.00       16000.00              90.00
#
#        Valor_m2_Barrio
# count          9520.00
# mean              4.60
# std               1.49
# min               0.16
# 25%               3.38
# 50%               4.57
# 75%               5.66
# max              10.25

# %%
pd.set_option('display.precision',2)
pd.set_option('display.float_format', lambda x: '%.2f' % x)
inmuebles.describe()
# Out:
#        Habitaciones   Banos      Area  Precio_Millon  Valor_m2_Millones  \
# count       9520.00 9520.00   9520.00        9520.00            9520.00
# mean           3.07    2.45    146.66         602.06               5.01
# std            2.05    1.26   1731.38         704.60               2.37
# min            1.00    0.00      2.00          60.00               0.01
# 25%            2.00    2.00     57.00         250.00               3.48
# 50%            3.00    2.00     80.00         409.18               4.67
# 75%            3.00    3.00    135.00         680.00               6.12
# max          110.00    9.00 166243.00       16000.00              90.00
#
#        Valor_m2_Barrio
# count          9520.00
# mean              4.60
# std               1.49
# min               0.16
# 25%               3.38
# 50%               4.57
# 75%               5.66
# max              10.25

# %% [markdown]
# **Error de digitación**

# %%
inmuebles.loc[inmuebles.Habitaciones == 110]
# Out:
#      Tipo                Descripcion  Habitaciones  Banos  Area    Barrio  \
# 897  Casa  Casa en venta en La Uribe           110      2   110  La Uribe
#
#          UPZ          Valor Moneda     Precio  Precio_Millon  \
# 897  Usaquén  $ 480.000.000      $  480000000         480.00
#
#      Valor_m2_Millones  Valor_m2_Barrio
# 897               4.36             4.27

# %% [markdown]
# **Error de digitación**

# %%
inmuebles.loc[inmuebles.Area == 2]
# Out:
#              Tipo                            Descripcion  Habitaciones  Banos  \
# 8401  Apartamento  Apartamento en venta en San Cristobal             3      1
#
#       Area         Barrio      UPZ          Valor Moneda     Precio  \
# 8401     2  San Cristobal  Sosiego  $ 180.000.000      $  180000000
#
#       Precio_Millon  Valor_m2_Millones  Valor_m2_Barrio
# 8401         180.00              90.00             2.95

# %%
inmuebles['Precio_Millon'].plot.hist(bins=10)
# Out:
# <Axes: ylabel='Frequency'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,6))
grafica = sns.histplot(data=inmuebles, x='Precio_Millon', kde=True, hue='Tipo')
grafica.set_title('Distribución de Valores de los inmuebles en Bogotá')
plt.xlim((50,1000))
plt.savefig('/content/drive/MyDrive/Alura_Latam_Python/valor_inmuebles.png', format='png')
plt.show()

# %% [markdown]
# **DESAFIO**
#
# 1. Estudiar mejor el histograma de valores y seleccionar 3 tipos de inmuebles.
#
# 2. Refinar el gráfico: títulos, aumentar el tamaños de labels, etc.
#
# 3. Conclusión de la información.
#
# 4. Precio del m2 por barrio y hacer el gráfico más adecuado para esta nueva variable.

# %%
#Primero consultamos cuáles son los tipos de inmuebles
inmuebles['Tipo'].value_counts()
# Out:
# Apartamento            7327
# Casa                   2043
# Oficina/Consultorio      60
# Local                    38
# Edificio                 22
# Bodega                   13
# Finca                    11
# Lote                      6
# Name: Tipo, dtype: int64

# %%
#Importamos las librerías
import matplotlib.pyplot as plt
import seaborn as sns

#Clonfiguramos el tamaño del lienzo
plt.figure(figsize=(12,6))

#Definimos la variable de los tipos de vivienda
tipos_viv = ['Apartamento', 'Casa', 'Oficina/Consultorio']
tipos_filtrados = inmuebles[inmuebles['Tipo'].isin(tipos_viv)]

#Definimos la paleta de colores para cada tipo de inmueble
palette = {'Apartamento': '#1f77b4', 'Casa': '#ff7f0e', 'Oficina/Consultorio': '#2ca02c'}

#Graficamos la distrubución de los precios por tipo de inmueble
grafica = sns.histplot(data=tipos_filtrados, x='Precio_Millon', kde=True, hue='Tipo', palette=palette)

#Se modifican los títulos para que sean más descriptivos
grafica.set(title='Distribución de los valores de 3 tipos de inmuebles en Bogotá', xlabel='Precio', ylabel='Frecuencia')

#Estilamos las etiquetas
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

#Limitamos el eje x para una mejor visualización
plt.xlim((50,1000))

#Código para configuración para guardado de la gráfica en algún formato
plt.savefig('/content/drive/MyDrive/Alura_Latam_Python/valor_tipos_inmuebles.png', format='png')
plt.show()

# %% [markdown]
# **Conclusión**
#
#
# 1.   La gran mayoría de los inmuebles se encuentran en el rango de 200 a 400 millones de pesos colombianos.
# 2.   El tipo de vivienda *"Apartamento"* es el que tiene más presencia en el mercado inmoviliario de la ciudad de Bogotá, no así, el tipo *"Oficina/Consultorio".*

# %%
#Calculamos el precio del m2 por barrio en la ciudad de Bogotá genera una nueva variable
precio_m2 = inmuebles['Precio_Millon'] / inmuebles['Area']
precio_m2_barrio = precio_m2.groupby(inmuebles['Barrio']).mean().sort_values(ascending=False).head(10)
print('Precio de m2 por', precio_m2_barrio)
# Out:
# Precio de m2 por Barrio
# El Virrey         10.20
# Santa Ana          9.36
# La Merced          8.98
# Chico Norte        8.54
# Los Rosales        8.17
# El Refugio         7.96
# Las Nieves         7.89
# El Retiro          7.72
# Chico Reservado    7.61
# Chapinero          7.43
# dtype: float64

# %%
#Importamos las librerías
import matplotlib.pyplot as plt
import seaborn as sns

#Clonfiguramos el tamaño del lienzo
plt.figure(figsize=(8,4))

#Definimos la paleta de colores para cada tipo de inmueble
color_barra = plt.get_cmap('tab20').colors[:len(precio_m2_barrio)]

#Creamos el gráfico de barras
plt.bar(precio_m2_barrio.index, precio_m2_barrio, color=color_barra)

#Estilamos los títulos y las etiquetas
plt.title('Precio del m2 por barrio en la ciudad de Bogotá', fontsize=16)
plt.xlabel('Barrio', fontsize=14)
plt.ylabel('Precio del m2 por barrio (millones de pesos colombianos)', fontsize=12)
plt.xticks(rotation=90, fontsize=12)

#Código para configuración para guardado de la gráfica en algún formato
plt.savefig('/content/drive/MyDrive/Alura_Latam_Python/valor_barrios_m2.png', format='png')
plt.show()

# %% [markdown]
# ### **AULA 03**

# %%
#Buscamos otras maneras de resolver los desafíos del Aula 02. 
#Tomamos como referencia el precio de todo el dataset, dividivo por el área del dataset.
inmuebles['Valor_m2_Millones'] = inmuebles['Precio_Millon']/inmuebles['Area']
inmuebles.head(3)
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
#
#    Banos  Area              Barrio                                 UPZ  \
# 0      2    70  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla         KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
#
#              Valor Moneda      Precio  Precio_Millon  Valor_m2_Millones
# 0    $ 360.000.000      $   360000000         360.00               5.14
# 1    $ 670.000.000      $   670000000         670.00               3.94
# 2  $ 1.120.000.000      $  1120000000        1120.00               7.78

# %%
inmuebles.groupby('Barrio').mean()
# Out:
#                     Habitaciones  Banos   Area  Precio_Millon  \
# Barrio
# Alameda                     3.00   2.00  97.00         580.00
# Alhambra                    3.00   2.94 190.41         752.35
# Andes Norte                 3.00   2.86 124.86         709.57
# Antonio Nariño              4.31   2.50 163.06         459.22
# Barrancas                   2.87   2.13  70.20         314.13
# ...                          ...    ...    ...            ...
# Villa Maria                 4.69   3.69 207.15         402.85
# Villas De Granada           3.45   2.32  86.59         282.30
# Villemar                    2.94   2.06  76.89         303.83
# Zona Franca                 2.00   1.00  54.00         160.00
# Zona Noroccidental          3.17   2.51 135.79         620.81
#
#                     Valor_m2_Millones
# Barrio
# Alameda                          5.98
# Alhambra                         4.33
# Andes Norte                      6.05
# Antonio Nariño                   3.53
# Barrancas                        4.42
# ...                               ...
# Villa Maria                      2.04
# Villas De Granada                3.17
# Villemar                         3.99
# Zona Franca                      2.96
# Zona Noroccidental               4.62
#
# [149 rows x 5 columns]

# %%
datos_barrio = inmuebles.groupby('Barrio').sum()
datos_barrio
# Out:
#                     Habitaciones  Banos    Area  Precio_Millon  \
# Barrio
# Alameda                        3      2      97         580.00
# Alhambra                      51     50    3237       12790.00
# Andes Norte                   21     20     874        4967.00
# Antonio Nariño               207    120    7827       22042.65
# Barrancas                     43     32    1053        4712.00
# ...                          ...    ...     ...            ...
# Villa Maria                   61     48    2693        5237.00
# Villas De Granada             76     51    1905        6210.62
# Villemar                      53     37    1384        5469.00
# Zona Franca                    2      1      54         160.00
# Zona Noroccidental          2778   2204  119084      544453.06
#
#                     Valor_m2_Millones
# Barrio
# Alameda                          5.98
# Alhambra                        73.56
# Andes Norte                     42.35
# Antonio Nariño                 169.47
# Barrancas                       66.24
# ...                               ...
# Villa Maria                     26.58
# Villas De Granada               69.71
# Villemar                        71.81
# Zona Franca                      2.96
# Zona Noroccidental            4049.16
#
# [149 rows x 5 columns]

# %%
datos_barrio['Valor_m2_Barrio'] = datos_barrio['Precio_Millon']/datos_barrio['Area']
datos_barrio
# Out:
#                     Habitaciones  Banos    Area  Precio_Millon  \
# Barrio
# Alameda                        3      2      97         580.00
# Alhambra                      51     50    3237       12790.00
# Andes Norte                   21     20     874        4967.00
# Antonio Nariño               207    120    7827       22042.65
# Barrancas                     43     32    1053        4712.00
# ...                          ...    ...     ...            ...
# Villa Maria                   61     48    2693        5237.00
# Villas De Granada             76     51    1905        6210.62
# Villemar                      53     37    1384        5469.00
# Zona Franca                    2      1      54         160.00
# Zona Noroccidental          2778   2204  119084      544453.06
#
#                     Valor_m2_Millones  Valor_m2_Barrio
# Barrio
# Alameda                          5.98             5.98
# Alhambra                        73.56             3.95
# Andes Norte                     42.35             5.68
# Antonio Nariño                 169.47             2.82
# Barrancas                       66.24             4.47
# ...                               ...              ...
# Villa Maria                     26.58             1.94
# Villas De Granada               69.71             3.26
# Villemar                        71.81             3.95
# Zona Franca                      2.96             2.96
# Zona Noroccidental            4049.16             4.57
#
# [149 rows x 6 columns]

# %%
m2_barrio = dict(datos_barrio['Valor_m2_Barrio'])

# %%
inmuebles['Valor_m2_Barrio'] = inmuebles['Barrio']
inmuebles['Valor_m2_Barrio'] = inmuebles['Valor_m2_Barrio'].map(m2_barrio)
inmuebles.head(5)
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Banos  Area              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor Moneda      Precio  Precio_Millon  Valor_m2_Millones  \
# 0    $ 360.000.000      $   360000000         360.00               5.14
# 1    $ 670.000.000      $   670000000         670.00               3.94
# 2  $ 1.120.000.000      $  1120000000        1120.00               7.78
# 3    $ 890.000.000      $   890000000         890.00               5.78
# 4    $ 970.000.000      $   970000000         970.00               7.58
#
#    Valor_m2_Barrio
# 0             4.57
# 1             3.40
# 2             8.10
# 3             5.66
# 4             6.29

# %%
top_barrios = inmuebles['Barrio'].value_counts()[:10].index

# %%
datos_barrio.reset_index(inplace=True)
datos_barrio
# Out:
#                  Barrio  Habitaciones  Banos    Area  Precio_Millon  \
# 0               Alameda             3      2      97         580.00
# 1              Alhambra            51     50    3237       12790.00
# 2           Andes Norte            21     20     874        4967.00
# 3        Antonio Nariño           207    120    7827       22042.65
# 4             Barrancas            43     32    1053        4712.00
# ..                  ...           ...    ...     ...            ...
# 144         Villa Maria            61     48    2693        5237.00
# 145   Villas De Granada            76     51    1905        6210.62
# 146            Villemar            53     37    1384        5469.00
# 147         Zona Franca             2      1      54         160.00
# 148  Zona Noroccidental          2778   2204  119084      544453.06
#
#      Valor_m2_Millones  Valor_m2_Barrio
# 0                 5.98             5.98
# 1                73.56             3.95
# 2                42.35             5.68
# 3               169.47             2.82
# 4                66.24             4.47
# ..                 ...              ...
# 144              26.58             1.94
# 145              69.71             3.26
# 146              71.81             3.95
# 147               2.96             2.96
# 148            4049.16             4.57
#
# [149 rows x 7 columns]

# %%
datos_barrio.query('Barrio in @top_barrios')
# Out:
#                  Barrio  Habitaciones  Banos    Area  Precio_Millon  \
# 5        Barrios Unidos          1525   1196   87799      259877.76
# 10                 Bosa          1743    789   34879       93400.56
# 22             Cedritos          1458   1348   53711      270027.73
# 24            Chapinero           892    913   81248      372130.93
# 50             Engativa          1676   1077   59808      172711.73
# 63              Kennedy          2151   1233   61475      207963.65
# 125       Santa Barbara          1073   1162   54693      320097.80
# 132                Suba          1497   1202   61615      266406.04
# 138             Usaquén          3109   3044  148121      837710.36
# 148  Zona Noroccidental          2778   2204  119084      544453.06
#
#      Valor_m2_Millones  Valor_m2_Barrio
# 5              2070.61             2.96
# 10             1654.36             2.68
# 22             2853.23             5.03
# 24             2466.03             4.58
# 50             1795.71             2.89
# 63             2127.66             3.38
# 125            2701.88             5.85
# 132            2000.72             4.32
# 138            6334.04             5.66
# 148            4049.16             4.57

# %%
plt.figure(figsize=(10,8))
#Además del gráfico de barras podemos tener la descripción estadística, para eso usamos bloxplot (gráfico de cajas) y eliminamos sns.barplot
ax = sns.boxplot(x='Barrio', y='Valor_m2_Barrio',data = datos_barrio.query('Barrio in @top_barrios'))
ax.tick_params(axis='x', rotation=45)
plt.show()

# %%
#De aciuerdo con el gráfico anterior, no tiene mucho sentido verificar el comportamiento del área, por lo mismo mejor lo cambiamos a precios.
plt.figure(figsize=(10,8))
#Además del gráfico de barras podemos tener la descripción estadística, para eso usamos bloxplot (gráfico de cajas) y eliminamos sns.barplot
#Se calcula sobre inmuebles totales y no datos barrio, ya que los datos sin insuficientes.
ax = sns.boxplot(x='Barrio', y='Valor_m2_Millones',data = inmuebles.query('Barrio in @top_barrios'))
ax.tick_params(axis='x', rotation=45)
plt.show()
#Los outlayes son los datos discrepantes, muy fuera del comportamiento normal

# %%
plt.figure(figsize=(10,8))
ax = sns.boxplot(x='Barrio', y='Valor_m2_Millones',data = inmuebles.query('Barrio in @top_barrios & Valor_m2_Millones < 15'))
ax.tick_params(axis='x', rotation=45)
plt.show()

# %%
plt.figure(figsize=(10,8))
ax = sns.boxplot(x='Barrio', y='Area',data = inmuebles.query('Barrio in @top_barrios & Area < 500'))
ax.tick_params(axis='x', rotation=45)
plt.show()

# %%
plt.figure(figsize=(10,8))
ax = sns.boxplot(x='Barrio', y='Precio_Millon',data = inmuebles.query('Barrio in @top_barrios & Precio_Millon < 2000'))
ax.tick_params(axis='x', rotation=45)
plt.show()

# %% [markdown]
# **INSTRUCCIÓN EXTRA**
#
# Vamor a traer datos estadísticos de la ciudad de Bogotá, directamente del DANE y vamos a ver como estos datos nos ayudarán en inclusión de nuevas variables para el cálculo del precio de los inmuebles en la ciudad de Bogotá.
#
# Encuesta multipropósito de Bogotá para obtener información socio - económica y de entorno urbano de los habitantes de Bogotá para la formulación, seguimiento y evaluación de las políticas distritales.
#
# https://microdatos.dane.gov.co/index.php/catalog/743

# %%
datos_raw = pd.read_csv('/content/drive/MyDrive/Alura_Latam_Python/Identificación (Capítulo A).csv', sep=';', encoding='latin-1')
datos_raw.head()
# Out:
#    DIRECTORIO  DPTO   MPIO  CLASE  COD_LOCALIDAD NOMBRE_LOCALIDAD  \
# 0  3004346.00    11  11001      1           3.00         Santa Fe
# 1  3004347.00    11  11001      1          14.00     Los Mártires
# 2  3004348.00    11  11001      1           3.00         Santa Fe
# 3  3004349.00    11  11001      1           1.00          Usaquén
# 4  3004350.00    11  11001      1           1.00          Usaquén
#
#    COD_UPZ_GRUPO                        NOMBRE_UPZ_GRUPO  ESTRATO2021  \
# 0         814.00  SANTA FE: Las Nieves + Sagrado Corazón     11001187
# 1          37.00                            Santa Isabel     11001162
# 2         814.00  SANTA FE: Las Nieves + Sagrado Corazón     11001187
# 3         803.00   USAQUÉN: Country Club + Santa Bárbara     11001176
# 4         803.00   USAQUÉN: Country Club + Santa Bárbara     11001176
#
#                            NOMBRE_ESTRATO             FEX_C
# 0  SANTA FE: Las Nieves + Sagrado Corazón  13,2266692027239
# 1                            Santa Isabel  17,8555889419101
# 2  SANTA FE: Las Nieves + Sagrado Corazón  10,0286103658331
# 3   USAQUÉN: Country Club + Santa Bárbara  28,6502122142802
# 4   USAQUÉN: Country Club + Santa Bárbara  24,4684068319009

# %%
datos_raw.shape
# Out:
# (106467, 11)

# %%
datos_raw = datos_raw.loc[datos_raw.MPIO == 11001]
datos_raw.shape
# Out:
# (86504, 11)

# %%
datos_b = pd.read_csv('/content/drive/MyDrive/Alura_Latam_Python/Datos de la vivenda y su entorno (Capítulo B).csv', sep=';', encoding='latin-1')
datos_c = pd.read_csv('/content/drive/MyDrive/Alura_Latam_Python/Condiciones habitacionales del hogar (Capítulo C).csv', sep=';', encoding='latin-1') 
datos_e = pd.read_csv('/content/drive/MyDrive/Alura_Latam_Python/Composición del hogar y demografía (Capítulo E).csv', sep=';', encoding='latin-1')
datos_h = pd.read_csv('/content/drive/MyDrive/Alura_Latam_Python/Educación (Capítulo H).csv', sep=';', encoding='latin-1')
datos_l = pd.read_csv('/content/drive/MyDrive/Alura_Latam_Python/Percepción sobre las condiciones de vida y el desempeño institucional (Capítulo L).csv', sep=';', encoding='latin-1')
datos_k = pd.read_csv('/content/drive/MyDrive/Alura_Latam_Python/Fuerza de trabajo (Capítulo K).csv', sep=';', encoding='latin-1')
# Out:
# <ipython-input-76-76faa168677e>:2: DtypeWarning: Columns (4,25,30,47) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos_c = pd.read_csv('/content/drive/MyDrive/Alura_Latam_Python/Condiciones habitacionales del hogar (Capítulo C).csv', sep=';', encoding='latin-1')
# <ipython-input-76-76faa168677e>:3: DtypeWarning: Columns (66) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos_e = pd.read_csv('/content/drive/MyDrive/Alura_Latam_Python/Composición del hogar y demografía (Capítulo E).csv', sep=';', encoding='latin-1')
# <ipython-input-76-76faa168677e>:4: DtypeWarning: Columns (81) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos_h = pd.read_csv('/content/drive/MyDrive/Alura_Latam_Python/Educación (Capítulo H).csv', sep=';', encoding='latin-1')
# <ipython-input-76-76faa168677e>:5: DtypeWarning: Columns (114,117,122,126,164,166,168) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos_l = pd.read_csv('/content/drive/MyDrive/Alura_Latam_Python/Percepción sobre las condiciones de vida y el desempeño institucional (Capítulo L).csv', sep=';', encoding='latin-1')
# <ipython-input-76-76faa168677e>:6: DtypeWarning: Columns (27,58,60,62,64,66,104,114,120,124,126,129,131,133) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos_k = pd.read_csv('/content/drive/MyDrive/Alura_Latam_Python/Fuerza de trabajo (Capítulo K).csv', sep=';', encoding='latin-1')

# %%
datos_dane = pd.merge(datos_raw,datos_b,on='DIRECTORIO', how='left')
datos_dane.shape
# Out:
# (86504, 73)

# %%
datos_dane = pd.merge(datos_dane,datos_c,on='DIRECTORIO', how='left')
datos_dane.shape
# Out:
# (87061, 214)

# %%
datos_dane.shape
# Out:
# (238559, 281)

# %%
datos_dane.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 238559 entries, 0 to 238558
# Columns: 281 entries, DIRECTORIO to FEX_C_y
# dtypes: float64(140), int64(126), object(15)
# memory usage: 513.3+ MB

# %% [markdown]
# ### **DESAFiO**
#
# 1. Dar un vistazO a la base de datos del DANE, entender estas variables conceptualmente para entender mejor el contexto de esta base.
#
# 2. Organizar tu notebook para que tu proyecto quede mejor presentado.
